# %% [markdown]
# # Lesson 11 Self-Check
#
# - run the cell below to load the self-check quiz.
# - make sure to save the notebook to preserve your answers
# - you may re-run the code to execute the quiz again.

# %%
from casstools.interact_quiz import render_quiz
render_quiz("11-self-check.json")
# Out:
# <h2>11 Self Check
# <h3>Question 1
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What does the pd.json_normalize() function do that…
# <h3>Question 2
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: When scraping HTML tables with pd.re…
# <h3>Question 3
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the difference between pd.concat() and pd.…
# <h3>Question 4
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: In a pd.merge() operation, what does…
# <h3>Question 5
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the purpose of the lambda function in df.a…
# <h3>Question 6
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Given this code, what will be the value of result?…
# <h3>Question 7
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the homework: What Python module/function is …
# <h3>Question 8
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>When using pd.json_normalize() with the record_pat…
# <h3>Question 9
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the homework: In the extract_colors() functio…
# <h3>Question 10
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What does the DataFrame.iterrows() method return?<…
