# %% [markdown]
# # Code Samples From Large Group
#
# Place your notes and code samples from large group here.

# %%
import pandas as pd 
import numpy as np

# %%
names = pd.Series(data=["Art", "Bette", "Chris"], name="first_name")

# %%
names
# Out:
# 0      Art
# 1    Bette
# 2    Chris
# Name: first_name, dtype: object

# %%
grades = pd.Series(data=[100, 100, 75], name="grades")
grades
# Out:
# 0    100
# 1    100
# 2     75
# Name: grades, dtype: int64

# %%
students = pd.DataFrame({ "name":names, "grade": grades})
students
# Out:
#     name  grade
# 0    Art    100
# 1  Bette    100
# 2  Chris     75

# %%
data = [
    {"name": "Bob", "state": "NY", "years": 15},
    {"name": "Tad", "state": "NY"},
    {"name": "Kelly", "state": "PA", "years": 25},
    {"name": "Shelly", "state": "PA", "years": 5}
]

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      name state  years
# 0     Bob    NY   15.0
# 1     Tad    NY    NaN
# 2   Kelly    PA   25.0
# 3  Shelly    PA    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   state   4 non-null      object
#  2   years   3 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 228.0+ bytes

# %%
df.columns
# Out:
# Index(['name', 'state', 'years'], dtype='object')

# %%
for col in df.columns:
    print(col)
# Out:
# name
# state
# years

# %%
df.columns = [ "senator_name", "senator_state", "senator_years"]

# %%
df
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
data
# Out:
# [{'name': 'Bob', 'state': 'NY', 'years': 15},
#  {'name': 'Tad', 'state': 'NY'},
#  {'name': 'Kelly', 'state': 'PA', 'years': 25},
#  {'name': 'Shelly', 'state': 'PA', 'years': 5}]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df)
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
df
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
from IPython.display import display

display(df)
display(df)
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
df
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
df2 = df[["senator_name", "senator_state"]]

# %%
df2
# Out:
#   senator_name senator_state
# 0          Bob            NY
# 1          Tad            NY
# 2        Kelly            PA
# 3       Shelly            PA

# %%
df3 = df[df['senator_state'] == 'NY']

# %%
df3
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN

# %%
df
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
df[ df['senator_state'] =='PA'][['senator_name']]
# Out:
#   senator_name
# 2        Kelly
# 3       Shelly

# %%
something = df.loc[2, "senator_name"]
print(something)
# Out:
# Kelly

# %%
df
# Out:
#   senator_name senator_state  senator_years
# 0          Bob            NY           15.0
# 1          Tad            NY            NaN
# 2        Kelly            PA           25.0
# 3       Shelly            PA            5.0

# %%
df["senator_name"]
# Out:
# 0       Bob
# 1       Tad
# 2     Kelly
# 3    Shelly
# Name: senator_name, dtype: object

# %%
df['senator_state'].unique()
# Out:
# array(['NY', 'PA'], dtype=object)

# %%
df['senator_state'].value_counts()
# Out:
# senator_state
# NY    2
# PA    2
# Name: count, dtype: int64

# %%
df[["senator_name"]]

# %%
type(df["senator_state"])
# Out:
# pandas.core.series.Series

# %%
dedupe_states = sorted(list(df["senator_state"].unique()))
dedupe_states
# Out:
# ['NY', 'PA']

# %%
df["senator_state"].unique()
# Out:
# array(['NY', 'PA'], dtype=object)

# %%
file = "https://raw.githubusercontent.com/mafudge/datasets/master/superhero/superhero-movie-dataset-1978-2012-header.csv"
df = pd.read_csv(file, header=0, sep=",")

# %%
df
# Out:
#     Year                                      Title   Comic  IMDB Score  \
# 0   1978                                   Superman      DC         7.3
# 1   1980                                Superman II      DC         6.7
# 2   1982                                Swamp Thing      DC         5.3
# 3   1983                               Superman III      DC         4.9
# 4   1984                                  Supergirl      DC         4.2
# 5   1986                            Howard the Duck  Marvel         4.3
# 6   1987           Superman IV: The Quest for Peace      DC         3.6
# 7   1989                                     Batman      DC         7.6
# 8   1989                  The Return of Swamp Thing      DC         3.9
# 9   1989                               The Punisher  Marvel         5.4
# 10  1992                             Batman Returns      DC         7.0
# 11  1995                             Batman Forever      DC         5.4
# ...

# %%
students = pd.read_csv(
    "https://raw.githubusercontent.com/mafudge/datasets/master/delimited/students-header.psv",
    sep="|"
)

# %%
students
# Out:
#      Name  Grade       Year
# 0    Abby    7.0   Freshman
# 1     Bob    9.0  Sophomore
# 2   Chris   10.0     Senior
# 3    Dave    8.0   Freshman
# 4   Ellen    7.0  Sophomore
# 5    Fran   10.0     Senior
# 6    Greg    8.0   Freshman
# 7   Helen    NaN  Sophomore
# 8    Iris   10.0     Senior
# 9   Jimmy    8.0   Freshman
# 10  Karen    7.5   Freshman
# 11  Lynne   10.0  Sophomore
# 12   Mike   10.0  Sophomore
# 13   Nico    NaN     Junior
# 14   Pete    8.0   Freshman

# %%
df.info()

# %%
df.describe()

# %%
df.head(n=7)

# %%
df.tail(n=3)

# %%
df['Comic'].value_counts()

# %%
df['Year'].value_counts()

# %%
df2000 = df[df['Year'] >= 2000]

# %%
df2000['Comic'].value_counts()

# %%
df.dropna()

# %%
df.to_csv("super.csv")

# %%
students
# Out:
#      Name  Grade       Year
# 0    Abby    7.0   Freshman
# 1     Bob    9.0  Sophomore
# 2   Chris   10.0     Senior
# 3    Dave    8.0   Freshman
# 4   Ellen    7.0  Sophomore
# 5    Fran   10.0     Senior
# 6    Greg    8.0   Freshman
# 7   Helen    NaN  Sophomore
# 8    Iris   10.0     Senior
# 9   Jimmy    8.0   Freshman
# 10  Karen    7.5   Freshman
# 11  Lynne   10.0  Sophomore
# 12   Mike   10.0  Sophomore
# 13   Nico    NaN     Junior
# 14   Pete    8.0   Freshman

# %%
# first I need to know what columns
students.columns
# Out:
# Index(['Name', 'Grade', 'Year'], dtype='object')

# %%
# this gets the unique counts by year
students['Year'].value_counts()
# Out:
# Year
# Freshman     6
# Sophomore    5
# Senior       3
# Junior       1
# Name: count, dtype: int64

# %%
#I wonder who that jr. is?
students[ students['Year'] == 'Junior' ]
# Out:
#     Name  Grade    Year
# 13  Nico    NaN  Junior

# %%
# distribution of grade
students['Grade'].value_counts()
# Out:
# Grade
# 10.0    5
# 8.0     4
# 7.0     2
# 9.0     1
# 7.5     1
# Name: count, dtype: int64

# %%
students[ students["Grade"] >= 9.0 ]
# Out:
#      Name  Grade       Year
# 1     Bob    9.0  Sophomore
# 2   Chris   10.0     Senior
# 5    Fran   10.0     Senior
# 8    Iris   10.0     Senior
# 11  Lynne   10.0  Sophomore
# 12   Mike   10.0  Sophomore

# %%
# save in a variable
high_achievers = students[ students["Grade"] >= 9.0 ]
high_achievers.to_excel("high-achievers.xlsx", index=False)

# %%
bench = pd.read_excel("BenchmarkTests.xls")
bench
# Out:
#         IBM SATA SAN        \\128.230.182.202\BenchmarkTest\
# 0      Seneca 1U HDD  \\ist-s-archive1.ad.syr.edu\Benchmark\
# 1  Dell R200 - ITELL              \\128.230.38.57\Benchmark\
# 2   Dell 775N - IMG1  \\ist-s-img1.ad.syr.edu\BenchmarkTest\
# 3           G: Drive                                     NaN

# %%
file = "https://raw.githubusercontent.com/mafudge/datasets/master/superhero/superhero-movie-dataset-1978-2012-header.csv"
sh = pd.read_csv(file, header=0, sep=",")
sh.head(n=4)
# Out:
#    Year         Title Comic  IMDB Score  RT Score  Composite Score  \
# 0  1978      Superman    DC         7.3        95             84.0
# 1  1980   Superman II    DC         6.7        88             77.5
# 2  1982   Swamp Thing    DC         5.3        60             56.5
# 3  1983  Superman III    DC         4.9        24             36.5
#
#    Opening Weekend  Box Office  Avg Ticket Price  Opening Weekend Attendance  \
# 0                    7465343.0              2.34                 3190317.521
# 1                   14100523.0              2.69                 5241830.112
# 2                          NaN              2.94                         NaN
# 3                   13352357.0              3.15                 4238843.492
#
#    US Population That Year
# 0                222584545
# 1                227224681
# 2                231664458
# 3                233791994

# %%
# first 3
sh.head(n=3)
# Out:
#    Year        Title Comic  IMDB Score  RT Score  Composite Score  \
# 0  1978     Superman    DC         7.3        95             84.0
# 1  1980  Superman II    DC         6.7        88             77.5
# 2  1982  Swamp Thing    DC         5.3        60             56.5
#
#    Opening Weekend  Box Office  Avg Ticket Price  Opening Weekend Attendance  \
# 0                    7465343.0              2.34                 3190317.521
# 1                   14100523.0              2.69                 5241830.112
# 2                          NaN              2.94                         NaN
#
#    US Population That Year
# 0                222584545
# 1                227224681
# 2                231664458

# %%
sh.tail(n=5)
# Out:
#     Year                             Title   Comic  IMDB Score  RT Score  \
# 44  2011                X-Men: First Class  Marvel         7.9        87
# 45  2012             Marvel's The Avengers  Marvel         8.7        92
# 46  2012             The Dark Knight Rises      DC         9.1        86
# 47  2012  Ghost Rider: Spirit of Vengeance  Marvel         4.5        17
# 48  2012            The Amazing Spider-Man  Marvel         7.6        74
#
#     Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 44             83.0                   55101604.0              7.93
# 45             89.5                  207438708.0              7.92
# 46             88.5                  160887295.0              7.92
# 47             31.0                   22115334.0              7.92
# 48             75.0                   62004688.0              7.92
#
#     Opening Weekend Attendance  US Population That Year
# 44                6.948500e+06                311591917
# ...

# %%
sh.sample(n=5)
# Out:
#     Year                               Title   Comic  IMDB Score  RT Score  \
# 41  2011  Captain America: The First Avenger  Marvel         6.8        79
# 39  2010                          Iron Man 2  Marvel         7.1        74
# 45  2012               Marvel's The Avengers  Marvel         8.7        92
# 37  2009                            Watchmen      DC         7.7        64
# 24  2004                        The Punisher  Marvel         6.4        29
#
#     Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 41             73.5                   65058524.0              7.93
# 39             72.5                  128122480.0              7.89
# 45             89.5                  207438708.0              7.92
# 37             70.5                   55214334.0              7.50
# 24             46.5                   13834527.0              6.21
#
#     Opening Weekend Attendance  US Population That Year
# ...

# %%
# what are the Comic types?
sh['Comic'].unique()
# Out:
# array(['DC', 'Marvel'], dtype=object)

# %%
# How many movies?
len(sh)
# Out:
# 49

# %%
# counts of each comic
sh['Comic'].value_counts()
# Out:
# Comic
# Marvel    29
# DC        20
# Name: count, dtype: int64

# %%
sh.columns
# Out:
# Index(['Year', 'Title', 'Comic', 'IMDB Score', 'RT Score', 'Composite Score',
#        'Opening Weekend  Box Office', 'Avg Ticket Price',
#        'Opening Weekend Attendance', 'US Population That Year'],
#       dtype='object')

# %%
sh.head()
# Out:
#    Year         Title Comic  IMDB Score  RT Score  Composite Score  \
# 0  1978      Superman    DC         7.3        95             84.0
# 1  1980   Superman II    DC         6.7        88             77.5
# 2  1982   Swamp Thing    DC         5.3        60             56.5
# 3  1983  Superman III    DC         4.9        24             36.5
# 4  1984     Supergirl    DC         4.2         8             25.0
#
#    Opening Weekend  Box Office  Avg Ticket Price  Opening Weekend Attendance  \
# 0                    7465343.0              2.34                 3190317.521
# 1                   14100523.0              2.69                 5241830.112
# 2                          NaN              2.94                         NaN
# 3                   13352357.0              3.15                 4238843.492
# 4                    5738249.0              3.36                 1707812.202
#
#    US Population That Year
# 0                222584545
# 1                227224681
# ...

# %%
# all titles with "Super" in them
sh [ sh['Title'].str.startswith("Super") ]
# Out:
#     Year                             Title Comic  IMDB Score  RT Score  \
# 0   1978                          Superman    DC         7.3        95
# 1   1980                       Superman II    DC         6.7        88
# 3   1983                      Superman III    DC         4.9        24
# 4   1984                         Supergirl    DC         4.2         8
# 6   1987  Superman IV: The Quest for Peace    DC         3.6        10
# 28  2006                  Superman Returns    DC         6.3        76
#
#     Composite Score  Opening Weekend  Box Office  Avg Ticket Price  \
# 0              84.0                    7465343.0              2.34
# 1              77.5                   14100523.0              2.69
# 3              36.5                   13352357.0              3.15
# 4              25.0                    5738249.0              3.36
# 6              23.0                    5683122.0              3.91
# ...

# %%
#title with highest RT score
maxrt = sh['RT Score'].max()
sh[ sh['RT Score'] == maxrt ]
# Out:
#    Year     Title Comic  IMDB Score  RT Score  Composite Score  \
# 0  1978  Superman    DC         7.3        95             84.0
#
#    Opening Weekend  Box Office  Avg Ticket Price  Opening Weekend Attendance  \
# 0                    7465343.0              2.34                 3190317.521
#
#    US Population That Year
# 0                222584545

# %%
# Kaggle
