# %% [markdown]
# ### IST256 M001 Exam 1 (E1)
#
# - **2 minutes remain**
# - Todays' date is **3/2/2026**.
# - **Spread out** in the exam room!
# - Clear your desk of everything except your tip sheet and a pencil/pen.
# - Remove earbuds, smart glasses, put phone away and silence it. **AI violations**
# - Exam will not start until **all desks are clear**.
# - Fill out all information **legibly** on bubble sheet and question booklet.
# - Exam version is on the bottom right of inside pages of the question booklet.
# - Clearly mark your exam version on the bubble sheet!
# - We cannot answer questions about the exam. Too distracting for others.
# - When you are finished, bring up your bubble sheet, question book, and tip sheet.
# - Exam length is **45 minutes**. No late exams accepted.
