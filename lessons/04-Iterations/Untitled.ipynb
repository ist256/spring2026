# %%
# initalizers:
count = 0
count_a = 0
count_b = 0
count_c = 0
count_d = 0
count_f = 0
# main loop
while True:
    #input
    raw = input("Enter student score or 'quit' to exit:")
    # check for sentinel
    if raw == "quit":
        break

    # process
    grade = int(raw)
    count = count + 1
    if grade >=125:
        count_a += 1
    elif grade >=100:
        count_b += 1
    etc...

# output
print(f"COUNT: {count}")
# Out:
# Enter student score or 'quit' to exit: quit
