# %% [markdown]
# # Lesson 04 Self-Check
#
# - run the cell below to load the self-check quiz.
# - make sure to save the notebook to preserve your answers
# - you may re-run the code to execute the quiz again.

# %%
from casstools.interact_quiz import render_quiz
render_quiz("04-self-check.json")
# Out:
# <h2>04 Self Check
# <h3>Question 1
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the output of this code?</h4><pre style='b…
# <h3>Question 2
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Based on the homework assignment, if a student sco…
# <h3>Question 3
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: What is the purpose of a sentinel va…
# <h3>Question 4
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: In the Mississippi counting example,…
# <h3>Question 5
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What type of loop should you use when you know exa…
# <h3>Question 6
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>How many times will this loop execute?</h4><pre st…
# <h3>Question 7
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What Python keyword is used to immediately exit a …
# <h3>Question 8
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What will be the final value of count?</h4><pre st…
# <h3>Question 9
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Which statement best describes an infinite loop?</…
# <h3>Question 10
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the recommended pattern for writing indefi…
