# %% [markdown]
# # Code Samples From Large Group
#
# Place your notes and code samples from large group here. Your professor will share with you his code from large group.

# %%
print("Hi")
print("There")
# Out:
# Hi
# There

# %%
# To run a cell, SHIFT+ENTER

# %%
print("Yo!")
# Out:
# Yo!

# %%
name = input("Who are you?")
print("Hello,", name)
# Out:
# Who are you? Bob
# Hello, Bob

# %%
# New Way
name = input("Who are you?")
print(f"Hello {name}!")
# Out:
# Who are you? Dave
# Hello Dave!

# %%
# Why do input without a variable?
input("Enter your salary")
print("You make : ???")
# Out:
# Enter your salary 10000
# You make : ???

# %%
#input
name = input("Enter your name")
hourly_rate = input("How much do you make an hour?")
hours_worked = input("How many hours did you work?")

#process
total_pay = hourly_rate * hours_worked

#output
print(f"{name} has total pay of {total_pay}")
# Out:
# Enter your name Mike
# How much do you make an hour? 10
# How many hours did you work? 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 7
#       4 hours_worked = input("How many hours did you work?")
#       6 #process
# ----> 7 total_pay = hourly_rate * hours_worked
#       9 #output
#      10 print(f"{name} has total pay of {total_pay}")
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
#input
name = input("Enter your name")
hourly_rate = float(input("How much do you make an hour?"))
hours_worked = float(input("How many hours did you work?"))

#process
total_pay = hourly_rate * hours_worked

#output
print(f"{name} has total pay of {total_pay}")
# Out:
# Enter your name Jon Snow
# How much do you make an hour? 0.05
# How many hours did you work? 1000
# Jon Snow has total pay of 50.0

# %%
"100" + "5"
# Out:
# '1005'

# %%
100 + 5
# Out:
# 105

# %%
n = input("Enter number")
n + 5
# Out:
# Enter number 100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 n = input("Enter number")
# ----> 2 n + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
n
# Out:
# '100'

# %%
int("500")
# Out:
# 500

# %%
float("500")
# Out:
# 500.0

# %%
# End to End example

# %%
print("""
    There once was a man named [mans-name]. 
    He liked to eat [food-rhymes-with-name]. 
    One day he ate so much [food-rhymes-with-name], 
    that he got the [ailment], 
    and had to run to the [place-rhymes-with-name].
    """)
# Out:
#     There once was a man named [mans-name].
#     He liked to eat [food-rhymes-with-name].
#     One day he ate so much [food-rhymes-with-name],
#     that he got the [ailment],
#     and had to run to the [place-rhymes-with-name].

# %%
# interpolate
name = "Tony"
food = "Baloney"
ailment = "cramps"
place = "Barcaloni"

print(f"""
    There once was a man named {name}. 
    He liked to eat {food}. 
    One day he ate so much {food}, 
    that he got the {ailment}, 
    and had to run to {place}.
    """)
# Out:
#     There once was a man named Tony.
#     He liked to eat Baloney.
#     One day he ate so much Baloney,
#     that he got the cramps,
#     and had to run to Barcaloni.

# %%
# interpolate
name = input("Enter your name")
food = input(f"Enter a food that rhymes with {name}")
ailment = input("Enter illness")
place = input(f"Enter a place that rhymes with {name}")

print(f"""
    There once was a man named {name}. 
    He liked to eat {food}. 
    One day he ate so much {food}, 
    that he got the {ailment}, 
    and had to run to {place}.
    """)
# Out:
# Enter your name Carlo
# Enter a food that rhymes with Carlo Marlo Cheddar
# Enter illness flu
# Enter a place that rhymes with Carlo someplace better
#     There once was a man named Carlo.
#     He liked to eat Marlo Cheddar.
#     One day he ate so much Marlo Cheddar,
#     that he got the flu,
#     and had to run to someplace better.
