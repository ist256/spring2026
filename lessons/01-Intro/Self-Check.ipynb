# %% [markdown]
# # Lesson 01 Self-Check
#
# - run the cell below to load the self-check quiz.
# - make sure to save the notebook to preserve your answers
# - you may re-run the code to execute the quiz again.

# %%
from casstools.interact_quiz import render_quiz
render_quiz("01-self-check.json")
# Out:
# <h2>01 Self Check
# <h3>Question 1
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the purpose of variables in Python program…
# <h3>Question 2
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Which of the following is a valid Python variable …
# <h3>Question 3
# VBox(children=(HTML(value='<h4 style=\'margin-bottom: 10px;\'>From the lab: What happens when you run a progra…
# <h3>Question 4
# VBox(children=(HTML(value='<h4 style=\'margin-bottom: 10px;\'>What is the output of this code?</h4><pre style=…
# <h3>Question 5
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: What is the purpose of using f-strin…
# <h3>Question 6
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What symbol is used to concatenate (combine) strin…
# <h3>Question 7
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Which statement about the print() function is TRUE…
# <h3>Question 8
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Based on the homework assignment concept: Followin…
# <h3>Question 9
# VBox(children=(HTML(value='<h4 style=\'margin-bottom: 10px;\'>What will this code output?</h4><pre style=\'bac…
# <h3>Question 10
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the correct syntax to create an f-string t…
