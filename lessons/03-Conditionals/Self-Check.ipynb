# %% [markdown]
# # Lesson 03 Self-Check
#
# - run the cell below to load the self-check quiz.
# - make sure to save the notebook to preserve your answers
# - you may re-run the code to execute the quiz again.

# %%
from casstools.interact_quiz import render_quiz
render_quiz("03-self-check.json")
# Out:
# <h2>03 Self Check
# <h3>Question 1
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the value of result after this code execut…
# <h3>Question 2
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Based on the homework: What grade and grade points…
# <h3>Question 3
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: In the Rock, Paper, Scissors game, w…
# <h3>Question 4
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>From the lab: When should you use try...except for…
# <h3>Question 5
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Which relational operator would you use to check i…
# <h3>Question 6
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What is the result of this Boolean expression: Tru…
# <h3>Question 7
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What happens when you use elif instead of a series…
# <h3>Question 8
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>Which error type is raised when you try to convert…
# <h3>Question 9
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What will this code output when x = 25 and y = 6?<…
# <h3>Question 10
# VBox(children=(HTML(value="<h4 style='margin-bottom: 10px;'>What prints when the user enters 45s as input?</h4…
