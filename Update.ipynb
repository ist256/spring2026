# %% [markdown]
# # Update
#
# Run this code to get the latest files from your instructor!

# %%
# !/opt/startup.sh
# Out:
# ::: restoring git
# '/home/jovyan/library/.gitconfig' -> '/home/jovyan/.gitconfig'
# '/home/jovyan/library/.git-credentials' -> '/home/jovyan/.git-credentials'
# ::: pulling tools
# $ git fetch
#
# $ git reset --mixed
#
# $ git -c user.email=nbgitpuller@nbgitpuller.link -c user.name=nbgitpuller merge -Xours origin/main
#
# Already up to date.
#
# ::: symlinking tools
# ln: failed to create symbolic link '/opt/conda/lib/python3.12/site-packages/casstools': No such file or directory
# ::: puller file spring2026.txt
# ::: Puller course: ist256 This course:
# ::: making ist256 folder
# ::: Pulling https://github.com/ist256/spring2026.git on branch main for course  to path /home/jovyan/library/ist256/spring2026
# $ git fetch
#
# $ git reset --mixed
#
# $ git -c user.email=nbgitpuller@nbgitpuller.link -c user.name=nbgitpuller merge -Xours origin/main
#
# Already up to date.
#
# ::: jupyter lab extensions on by default
# ...
