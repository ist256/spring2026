# %% [markdown]
# # Update
#
# Run this code to get the latest files from your instructor!

# %%
# !/opt/startup.sh
# Out:
# ::: restoring git
# '/home/jovyan/library/.gitconfig' -> '/home/jovyan/.gitconfig'
# '/home/jovyan/library/.git-credentials' -> '/home/jovyan/.git-credentials'
# ::: pulling tools
# $ git fetch
#
# $ git reset --mixed
#
# $ git -c user.email=nbgitpuller@nbgitpuller.link -c user.name=nbgitpuller merge -Xours origin/main
#
# Already up to date.
#
# ::: symlinking tools
# ::: puller file spring2025.txt
# ::: Puller course: ist256 This course:
# ::: making ist256 folder
# ::: Pulling https://github.com/ist256/fall2025.git on branch main for course  to path /home/jovyan/library/ist256/fall2025
# $ git fetch
#
# $ git reset --mixed
#
# Unstaged changes after reset:
#
# M	lessons/01-Intro/Content.ipynb
#
# M	lessons/01-Intro/HW-Intro.ipynb
#
# M	lessons/02-Variables/Content.ipynb
#
# M	lessons/02-Variables/HW-Variables.ipynb
#
# M	lessons/02-Variables/LAB-Variables.ipynb
#
# M	lessons/02-Variables/Slides.ipynb
#
# ...
